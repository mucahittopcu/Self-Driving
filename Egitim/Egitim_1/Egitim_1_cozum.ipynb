# %%
import cv2
import matplotlib.pylab as plt
# %matplotlib inline

# %%
img_path = '/Users/yusufsatilmis/Desktop/Calisma_1/00001.jpg'

# %%
image = cv2.imread(img_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
img = image[0:376,0:672]

# %%
plt.imshow(img)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image)

# %%
cv2.putText(gray_image, "YUSUF SATILMIS", (40,70), cv2.FONT_HERSHEY_DUPLEX, 1.5, (200,255,155), 2, cv2.LINE_AA)

plt.imshow(gray_image)

# %%
img_save_path = '/Users/yusufsatilmis/Desktop/Calisma_1/00001_gray.jpg'
image = cv2.imwrite(img_save_path,gray_image)
